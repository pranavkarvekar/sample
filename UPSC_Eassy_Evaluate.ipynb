# %%
""""
Parallelization Workflow -> Feedback ,Score

StructuredOutModel


"""

# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv
from pydantic import BaseModel,Field
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
model = ChatGroq(
    model_name="openai/gpt-oss-120b",
    api_key=GROQ_API_KEY,
    temperature=0.7
)

# %%
class EvaluationSchema(BaseModel):
    feedback:str=Field(description="Detailed feedback on the essay")
    score:float=Field(description="Score out of 10 for the essay",ge=0,le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay="""Artificial Intelligence (AI) is one of the most transformative technologies of the 21st century. It refers to the simulation of human intelligence in machines that are programmed to think, learn, and perform tasks that traditionally required human cognitive abilities. AI has permeated almost every aspect of modern life, influencing how we work, communicate, and solve problems.

The primary role of AI is to enhance efficiency and decision-making. In industries such as healthcare, AI systems can analyze vast amounts of data to detect diseases early, predict outcomes, and recommend personalized treatment plans. In the business world, AI helps in automating repetitive tasks, managing inventory, and improving customer experiences through chatbots and recommendation systems.

Education is another field where AI has made a significant impact. Intelligent tutoring systems can adapt to the learning pace of individual students, providing personalized guidance and feedback. AI also aids researchers by processing large datasets, identifying patterns, and generating insights that would take humans years to discover.

Moreover, AI plays a vital role in improving safety and convenience in daily life. Self-driving cars, for example, use AI to interpret sensor data, predict traffic conditions, and make split-second driving decisions. Virtual assistants like Siri and Alexa make everyday tasks, from setting reminders to controlling smart home devices, more accessible and efficient.

However, the role of AI is not without challenges. Ethical concerns, such as privacy, bias, and job displacement, require careful consideration. The misuse of AI for surveillance, deepfakes, or autonomous weapons could pose serious societal risks. Therefore, alongside innovation, responsible development and regulation of AI are essential."""

# %%
prompt=f"You are an expert esay evaluator for UPSC exams{essay}\n"

# %%
structured_model.invoke(prompt).feedback
# Out:
# 'The essay provides a clear and concise overview of Artificial Intelligence, its applications, and associated challenges – a structure well‑suited for UPSC mains. \n\n**Strengths**\n1. **Introduction** – The opening defines AI succinctly and sets the context of its pervasive impact. \n2. **Logical Flow** – The body is divided into distinct sections (healthcare, business, education, daily life) which makes the argument easy to follow. \n3. **Use of Examples** – Real‑world illustrations such as self‑driving cars, chat‑bots, Siri/Alexa, and intelligent tutoring systems add credibility. \n4. **Balanced View** – The essay acknowledges both the benefits and the ethical/strategic challenges, an essential requirement for a UPSC answer.\n5. **Conclusion** – It ends with a call for responsible development and regulation, tying back to the introductory premise.\n\n**Areas for Improvement**\n1. **Depth of Analysis** – While the essay mentions several sectors, it could deepen the analysis by linking AI to specific policy frameworks (e.g., National AI Strategy, data‑privacy laws) and by providing quantitative impact where possible.\n2. **Critical Perspective** – A brief discussion on the trade‑offs (e.g., job displacement vs. new skill creation) and how governance can mitigate risks would strengthen the argument.\n3. **Coherence of Transitions** – Some paragraph transitions are abrupt; linking sentences (e.g., “Beyond industry, AI also reshapes everyday life…”) would improve flow.\n4. **Language & UPSC Tone** – A few sentences could be more concise, and the essay would benefit from occasional use of UPSC‑style terminology such as “social equity”, “technological determinism”, or “ethical governance”.\n5. **Structure** – Adding sub‑headings or a brief bullet‑point list of challenges and recommendations could make the essay more scannable for the examiner.\n\n**Overall Assessment** – The essay demonstrates good command over the topic, clear organization, and relevance to the UPSC syllabus. With deeper policy‑level insight and tighter cohesion, it could move from a solid answer to an excellent one.\n\n**Score**: 7.5/10'

# %%
structured_model.invoke(prompt).score
# Out:
# 7.5

# %%
from IPython.display import display, HTML

feedback = structured_model.invoke(prompt).feedback

display(HTML(f"""
<div style="overflow-x: auto; white-space: nowrap; border:1px solid #ccc; padding:10px;">
{feedback}
</div>
"""))
# Out:
# <div style="overflow-x: auto; white-space: nowrap; border:1px solid #ccc; padding:10px;">
# The essay provides a clear, well‑structured overview of artificial intelligence, covering definition, applications across sectors (healthcare, business, education, transportation, personal assistants) and the accompanying challenges. Strengths include:
#
# 1. **Coherent structure** – Introduction, role in various domains, and a concluding note on ethical concerns, which mirrors the classic UPSC essay format.
# 2. **Content breadth** – Adequate coverage of key sectors, with specific examples (early disease detection, chatbots, intelligent tutoring systems, self‑driving cars, Siri/Alexa) that demonstrate awareness of contemporary AI deployments.
# 3. **Balanced perspective** – The essay does not glorify AI; it acknowledges ethical issues such as privacy, bias, job loss, surveillance, deepfakes, and autonomous weapons, aligning with the UPSC expectation of a nuanced argument.
# 4. **Language and style** – The language is formal, concise, and free of colloquialisms. Sentences are generally well‑crafted, and terminology is appropriate for a UPSC audience.
#
# Areas for improvement:
#
# 1. **Depth of analysis** – While the essay mentions many applications, the discussion remains at a surface level. UPSC essays benefit from deeper analysis, e.g., citing statistics on AI‑driven diagnostic accuracy, or elaborating on how AI can augment rather than replace jobs.
# 2. **Critical linkage** – The essay could better link the benefits and challenges, perhaps by discussing the need for policy frameworks, data‑governance mechanisms, or capacity‑building in India to harness AI responsibly.
# 3. **Indian context** – Incorporating specific Indian initiatives (e.g., NITI Aayog’s AI strategy, Digital India projects, AI in Aadhaar, or AI‑enabled agricultural advisory services) would make the essay more relevant to the UPSC exam.
# 4. **Conclusion** – The ending could be stronger with a concise, forward‑looking statement that ties together the opportunities and responsibilities, possibly suggesting a way forward for India.
# 5. **Citation of examples** – Adding a recent, concrete example (e.g., AI used in COVID‑19 vaccine distribution, or IBM’s Watson Oncology) would enrich the narrative.
#
# Overall, the essay demonstrates good command over the topic and meets the basic criteria of a UPSC essay, but could be elevated with deeper insight, Indian-specific references, and a more compelling conclusion.
#
# **Score: 7.5/10** – The essay is solid but falls short of the higher band due to limited depth and lack of India‑centric examples.
# </div>

# %%
import textwrap

feedback = structured_model.invoke(prompt).feedback
print("\n".join(textwrap.wrap(feedback, width=100)))  # wrap at 100 chars
# Out:
# The essay presents a clear and well‑structured overview of Artificial Intelligence, covering its
# definition, applications across sectors, and associated challenges – a format that aligns well with
# the UPSC essay expectations.   **Strengths** 1. **Introduction & definition** – The opening
# succinctly defines AI and sets the context, which is essential for framing the discussion. 2.
# **Logical organization** – The essay follows a logical flow: definition → role in various sectors
# (healthcare, business, education, daily life) → challenges. Each paragraph begins with a topic
# sentence and is supported by concrete examples (e.g., disease detection, chatbots, self‑driving
# cars, Siri/Alexa). 3. **Breadth of coverage** – A wide range of domains is covered, demonstrating
# the candidate’s awareness of AI’s pervasive impact – a key criterion for UPSC. 4. **Balanced
# perspective** – The concluding paragraph rightly highlights ethical concerns and the need for
# regulation, showing critical thinking and a balanced stance. 5. **Clarity & language** – The
# language is precise, sentences are concise, and jargon is minimal, making the essay accessible.
# **Areas for improvement** 1. **Depth of analysis** – While breadth is good, UPSC essays reward
# deeper analysis. For example, the healthcare section could discuss specific AI models (e.g.,
# deep‑learning radiology tools) and their impact on rural health. The business section could mention
# AI‑driven supply‑chain optimization or predictive analytics. 2. **Linkages & synthesis** – The essay
# could benefit from stronger linkages between sections. A sentence that ties the efficiency gains in
# industry to the ethical concerns (e.g., job displacement) would improve coherence. 3. **Use of data/
# statistics** – Including a relevant statistic (e.g., "AI in healthcare is projected to save
# $150 billion annually by 2026") would add weight to the arguments. 4. **Counter‑argument & nuance**
# – Introducing a brief counter‑argument (e.g., "While AI can augment decision‑making, over‑reliance
# may erode human expertise") and then refuting it would showcase critical evaluation. 5.
# **Conclusion** – The conclusion currently repeats the challenges. A stronger UPSC conclusion would
# summarise the key arguments, reaffirm the balanced view, and possibly suggest a way forward (e.g.,
# "A robust regulatory framework coupled with skill‑upgradation programs can harness AI’s benefits
# while mitigating risks.")  **Overall assessment** – The essay meets the basic requirements of a UPSC
# answer: it is well‑structured, covers the topic comprehensively, and demonstrates awareness of both
# opportunities and pitfalls. With deeper analytical depth, integration of data, and a more nuanced
# conclusion, it could move from a good answer to an excellent one.  **Score**: 7.5/10

# %%
from IPython.display import display, HTML

feedback = structured_model.invoke(prompt).feedback

display(HTML(f"""
<div style="
    width: 800px;          /* fixed width for the container */
    max-height: 400px;     /* optional: max height */
    overflow: auto;        /* enables both horizontal & vertical scroll */
    white-space: pre;      /* preserves line breaks and spacing */
    border:1px solid #ccc;
    padding:10px;
">
{feedback}
</div>
"""))
# Out:
# <div style="
#     width: 800px;          /* fixed width for the container */
#     max-height: 400px;     /* optional: max height */
#     overflow: auto;        /* enables both horizontal & vertical scroll */
#     white-space: pre;      /* preserves line breaks and spacing */
#     border:1px solid #ccc;
#     padding:10px;
# ">
# The essay presents a clear and well‑structured overview of Artificial Intelligence, covering its definition, major applications, and associated challenges.
#
# **Strengths**:
# - **Logical flow**: The introduction sets the context, followed by distinct paragraphs on industry, healthcare, education, everyday life, and a concluding note on ethics and regulation.
# - **Breadth of coverage**: The writer mentions diverse sectors (healthcare, business, education, transportation, virtual assistants) and highlights both benefits and risks, which aligns with the UPSC emphasis on a balanced perspective.
# - **Clarity of language**: Vocabulary is appropriate for a UPSC essay, and sentences are generally concise and coherent.
# - **Use of examples**: References to self‑driving cars, Siri/Alexa, and chatbots make the discussion concrete.
#
# **Areas for improvement**:
# - **Indian context**: UPSC essays are expected to anchor arguments in the Indian scenario. Incorporating examples such as AI in Aadhaar, the National AI Strategy, or Indian startups in health‑tech would strengthen relevance.
# - **Depth of analysis**: The essay could delve deeper into policy implications, such as the need for data‑privacy legislation, skill‑retraining programmes, and the role of institutions like NITI Aayog.
# - **Critical nuance**: While the challenges are listed, a brief discussion on mitigation measures (ethical guidelines, bias‑audit frameworks, inclusive AI development) would demonstrate a more nuanced understanding.
# - **Conclusion**: The ending could be more impactful by summarizing key points and suggesting a forward‑looking statement on how India can harness AI responsibly.
#
# **Overall assessment**: The essay meets the basic criteria for a UPSC answer – it is well‑organized, covers multiple dimensions, and uses appropriate language. To reach a higher band, the writer should integrate Indian examples, elaborate on policy measures, and provide a sharper concluding insight.
#
# **Score**: 7.5/10
# </div>
